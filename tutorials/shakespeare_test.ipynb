# %% [markdown]
# # FLSim Tutorial: Next char prediction with LEAF's Shakespeare

# %% [markdown]
# ### Objectives
#
# By the end of this tutorial, we will have learnt how to
#
# 1. Build a data pipeline for federated learning with FLSim,
# 2. Create a next char prediction model compatible with FL training,
# 3. Create a metrics reporter to collect and report metrics,
# 4. Set hyperparameters for FL training, and
# 5. Launch an FL training flow using FLSim.

# %% [markdown]
# ## Training a next-char predictor with FLSim

# %% [markdown]
# ### Prerequisites
# First, let us install flsim via pip with the command below:

# %%
# !pip install --quiet flsim

# %% [markdown]
# Some useful parameters for later - no need to change these.

# %%
USE_CUDA = True
LOCAL_BATCH_SIZE = 32
SEQ_LEN = 80
# suppress large outputs
VERBOSE = False

# %% [markdown]
# ### 0. About the dataset
#
# For this tutorial, we will use [LEAF's](https://leaf.cmu.edu/) Shakespeare dataset
#
# Before the next step in this tutorial, we need to download the dataset and partition the data by users.
# In particular, we sample
# 5% of the entire dataset (`--sf 0.05`)
# in a non-IID manner (`-s niid`)
# and partition 90% of sampled users into train and 10% of sampled users
# into test (`--tf 0.90`) as opposed to splitting individual samples into train and test (`-t 'user'`) .
# We require all users to have at least one sample (`-k 1`).
#
# ```
# ./preprocess.sh -s niid --sf 0.05 -k 1 --tf 0.90 -t 'user'
#
# ```
#
# For more information on the various preprocessing options, see [here](https://github.com/TalwalkarLab/leaf/tree/master/data/shakespeare). You can find the LEAF paper [here](https://arxiv.org/pdf/1812.01097.pdf).

# %% [markdown]
# Let us now find our preprocessed data. Note that if you use different preprocessing options, you might need to change these!

# %%
import os
os.chdir('../../leaf/data/shakespeare')
TRAIN_DATA = os.listdir('data/train')
TRAIN_DATA = "data/train/" + TRAIN_DATA[0]

TEST_DATA = os.listdir('data/test')
TEST_DATA = "data/test/" + TEST_DATA[0]

TRAIN_DATA, TEST_DATA
# Out:
# ('data/train/all_data_0_05_keep_1_train_9.json',
#  'data/test/all_data_0_05_keep_1_test_9.json')

# %% [markdown]
# We can now load the training data and get a sense of how samples are distributed across users in our subset of the Sent140 dataset.

# %%
import json
import numpy as np

# load the training data
with open(TRAIN_DATA, "r") as f:
    training_data = json.load(f)

# how samples are distributed across users
n_samples = training_data['num_samples']
print(f"""\nNumber of samples per user:
  min={np.min(n_samples)}, 
  max={np.max(n_samples)}, 
  median={np.median(n_samples)}, 
  mean={np.mean(n_samples):.2f}, 
  std={np.std(n_samples):.2f}
  """)
# Out:
# Number of samples per user:
#   min=30,
#   max=26131,
#   median=1595.0,
#   mean=4012.76,
#   std=5671.36

# %% [markdown]
# Let us also look at the data for an example user. Notice that there are multiple metadata fields in addition to the tweet itself and its sentiment label.

# %%
EXAMPLE_USER = training_data["users"][0]
print(f"Example user: {EXAMPLE_USER}")
training_data["user_data"][EXAMPLE_USER]
# Out:
# Example user: THE_HISTORY_OF_TROILUS_AND_CRESSIDA_PARIS
# {'x': ['Else might the world convince of levity As well my undertakings as your counsels',
#   'lse might the world convince of levity As well my undertakings as your counsels;',
#   'se might the world convince of levity As well my undertakings as your counsels; ',
#   'e might the world convince of levity As well my undertakings as your counsels; B',
#   ' might the world convince of levity As well my undertakings as your counsels; Bu',
#   'might the world convince of levity As well my undertakings as your counsels; But',
#   'ight the world convince of levity As well my undertakings as your counsels; But ',
#   'ght the world convince of levity As well my undertakings as your counsels; But I',
#   'ht the world convince of levity As well my undertakings as your counsels; But I ',
#   't the world convince of levity As well my undertakings as your counsels; But I a',
#   ' the world convince of levity As well my undertakings as your counsels; But I at',
#   'the world convince of levity As well my undertakings as your counsels; But I att',
#   'he world convince of levity As well my undertakings as your counsels; But I atte',
#   'e world convince of levity As well my undertakings as your counsels; But I attes',
#   ' world convince of levity As well my undertakings as your counsels; But I attest',
#   'world convince of levity As well my undertakings as your counsels; But I attest ',
#   'orld convince of levity As well my undertakings as your counsels; But I attest t',
#   'rld convince of levity As well my undertakings as your counsels; But I attest th',
#   'ld convince of levity As well my undertakings as your counsels; But I attest the',
#   'd convince of levity As well my undertakings as your counsels; But I attest the ',
#   ' convince of levity As well my undertakings as your counsels; But I attest the g',
#   'convince of levity As well my undertakings as your counsels; But I attest the go',
#   'onvince of levity As well my undertakings as your counsels; But I attest the god',
#   'nvince of levity As well my undertakings as your counsels; But I attest the gods',
#   'vince of levity As well my undertakings as your counsels; But I attest the gods,',
#   'ince of levity As well my undertakings as your counsels; But I attest the gods, ',
#   'nce of levity As well my undertakings as your counsels; But I attest the gods, y',
#   'ce of levity As well my undertakings as your counsels; But I attest the gods, yo',
#   'e of levity As well my undertakings as your counsels; But I attest the gods, you',
#   ' of levity As well my undertakings as your counsels; But I attest the gods, your',
#   'of levity As well my undertakings as your counsels; But I attest the gods, your ',
#   'f levity As well my undertakings as your counsels; But I attest the gods, your f',
#   ' levity As well my undertakings as your counsels; But I attest the gods, your fu',
#   'levity As well my undertakings as your counsels; But I attest the gods, your ful',
#   'evity As well my undertakings as your counsels; But I attest the gods, your full',
#   'vity As well my undertakings as your counsels; But I attest the gods, your full ',
#   'ity As well my undertakings as your counsels; But I attest the gods, your full c',
#   'ty As well my undertakings as your counsels; But I attest the gods, your full co',
#   'y As well my undertakings as your counsels; But I attest the gods, your full con',
#   ' As well my undertakings as your counsels; But I attest the gods, your full cons',
#   'As well my undertakings as your counsels; But I attest the gods, your full conse',
#   's well my undertakings as your counsels; But I attest the gods, your full consen',
#   ' well my undertakings as your counsels; But I attest the gods, your full consent',
#   'well my undertakings as your counsels; But I attest the gods, your full consent ',
#   'ell my undertakings as your counsels; But I attest the gods, your full consent G',
#   'll my undertakings as your counsels; But I attest the gods, your full consent Ga',
#   'l my undertakings as your counsels; But I attest the gods, your full consent Gav',
#   ' my undertakings as your counsels; But I attest the gods, your full consent Gave',
#   'my undertakings as your counsels; But I attest the gods, your full consent Gave ',
#   'y undertakings as your counsels; But I attest the gods, your full consent Gave w',
#   ' undertakings as your counsels; But I attest the gods, your full consent Gave wi',
#   'undertakings as your counsels; But I attest the gods, your full consent Gave win',
#   'ndertakings as your counsels; But I attest the gods, your full consent Gave wing',
#   'dertakings as your counsels; But I attest the gods, your full consent Gave wings',
#   'ertakings as your counsels; But I attest the gods, your full consent Gave wings ',
#   'rtakings as your counsels; But I attest the gods, your full consent Gave wings t',
#   'takings as your counsels; But I attest the gods, your full consent Gave wings to',
#   'akings as your counsels; But I attest the gods, your full consent Gave wings to ',
#   'kings as your counsels; But I attest the gods, your full consent Gave wings to m',
#   'ings as your counsels; But I attest the gods, your full consent Gave wings to my',
#   'ngs as your counsels; But I attest the gods, your full consent Gave wings to my ',
#   'gs as your counsels; But I attest the gods, your full consent Gave wings to my p',
#   's as your counsels; But I attest the gods, your full consent Gave wings to my pr',
#   ' as your counsels; But I attest the gods, your full consent Gave wings to my pro',
#   'as your counsels; But I attest the gods, your full consent Gave wings to my prop',
#   's your counsels; But I attest the gods, your full consent Gave wings to my prope',
#   ' your counsels; But I attest the gods, your full consent Gave wings to my propen',
#   'your counsels; But I attest the gods, your full consent Gave wings to my propens',
#   'our counsels; But I attest the gods, your full consent Gave wings to my propensi',
#   'ur counsels; But I attest the gods, your full consent Gave wings to my propensio',
#   'r counsels; But I attest the gods, your full consent Gave wings to my propension',
#   ' counsels; But I attest the gods, your full consent Gave wings to my propension,',
#   'counsels; But I attest the gods, your full consent Gave wings to my propension, ',
#   'ounsels; But I attest the gods, your full consent Gave wings to my propension, a',
#   'unsels; But I attest the gods, your full consent Gave wings to my propension, an',
#   'nsels; But I attest the gods, your full consent Gave wings to my propension, and',
#   'sels; But I attest the gods, your full consent Gave wings to my propension, and ',
#   'els; But I attest the gods, your full consent Gave wings to my propension, and c',
#   'ls; But I attest the gods, your full consent Gave wings to my propension, and cu',
#   's; But I attest the gods, your full consent Gave wings to my propension, and cut',
#   '; But I attest the gods, your full consent Gave wings to my propension, and cut ',
#   ' But I attest the gods, your full consent Gave wings to my propension, and cut o',
#   'But I attest the gods, your full consent Gave wings to my propension, and cut of',
#   'ut I attest the gods, your full consent Gave wings to my propension, and cut of ',
#   't I attest the gods, your full consent Gave wings to my propension, and cut of A',
#   ' I attest the gods, your full consent Gave wings to my propension, and cut of Al',
#   'I attest the gods, your full consent Gave wings to my propension, and cut of All',
#   ' attest the gods, your full consent Gave wings to my propension, and cut of All ',
#   'attest the gods, your full consent Gave wings to my propension, and cut of All f',
#   'ttest the gods, your full consent Gave wings to my propension, and cut of All fe',
#   'test the gods, your full consent Gave wings to my propension, and cut of All fea',
#   'est the gods, your full consent Gave wings to my propension, and cut of All fear',
#   'st the gods, your full consent Gave wings to my propension, and cut of All fears',
#   't the gods, your full consent Gave wings to my propension, and cut of All fears ',
#   ' the gods, your full consent Gave wings to my propension, and cut of All fears a',
#   'the gods, your full consent Gave wings to my propension, and cut of All fears at',
#   'he gods, your full consent Gave wings to my propension, and cut of All fears att',
#   'e gods, your full consent Gave wings to my propension, and cut of All fears atte',
#   ' gods, your full consent Gave wings to my propension, and cut of All fears atten',
#   'gods, your full consent Gave wings to my propension, and cut of All fears attend',
#   'ods, your full consent Gave wings to my propension, and cut of All fears attendi',
#   'ds, your full consent Gave wings to my propension, and cut of All fears attendin',
#   's, your full consent Gave wings to my propension, and cut of All fears attending',
#   ', your full consent Gave wings to my propension, and cut of All fears attending ',
#   ' your full consent Gave wings to my propension, and cut of All fears attending o',
#   'your full consent Gave wings to my propension, and cut of All fears attending on',
#   'our full consent Gave wings to my propension, and cut of All fears attending on ',
#   'ur full consent Gave wings to my propension, and cut of All fears attending on s',
#   'r full consent Gave wings to my propension, and cut of All fears attending on so',
#   ' full consent Gave wings to my propension, and cut of All fears attending on so ',
#   'full consent Gave wings to my propension, and cut of All fears attending on so d',
#   'ull consent Gave wings to my propension, and cut of All fears attending on so di',
#   'll consent Gave wings to my propension, and cut of All fears attending on so dir',
#   'l consent Gave wings to my propension, and cut of All fears attending on so dire',
#   ' consent Gave wings to my propension, and cut of All fears attending on so dire ',
#   'consent Gave wings to my propension, and cut of All fears attending on so dire a',
#   'onsent Gave wings to my propension, and cut of All fears attending on so dire a ',
#   'nsent Gave wings to my propension, and cut of All fears attending on so dire a p',
#   'sent Gave wings to my propension, and cut of All fears attending on so dire a pr',
#   'ent Gave wings to my propension, and cut of All fears attending on so dire a pro',
#   'nt Gave wings to my propension, and cut of All fears attending on so dire a proj',
#   't Gave wings to my propension, and cut of All fears attending on so dire a proje',
#   ' Gave wings to my propension, and cut of All fears attending on so dire a projec',
#   'Gave wings to my propension, and cut of All fears attending on so dire a project',
#   'ave wings to my propension, and cut of All fears attending on so dire a project.',
#   've wings to my propension, and cut of All fears attending on so dire a project. ',
#   'e wings to my propension, and cut of All fears attending on so dire a project. F',
#   ' wings to my propension, and cut of All fears attending on so dire a project. Fo',
#   'wings to my propension, and cut of All fears attending on so dire a project. For',
#   'ings to my propension, and cut of All fears attending on so dire a project. For ',
#   'ngs to my propension, and cut of All fears attending on so dire a project. For w',
#   'gs to my propension, and cut of All fears attending on so dire a project. For wh',
#   's to my propension, and cut of All fears attending on so dire a project. For wha',
#   ' to my propension, and cut of All fears attending on so dire a project. For what',
#   'to my propension, and cut of All fears attending on so dire a project. For what,',
#   'o my propension, and cut of All fears attending on so dire a project. For what, ',
#   ' my propension, and cut of All fears attending on so dire a project. For what, a',
#   'my propension, and cut of All fears attending on so dire a project. For what, al',
#   'y propension, and cut of All fears attending on so dire a project. For what, ala',
#   ' propension, and cut of All fears attending on so dire a project. For what, alas',
#   'propension, and cut of All fears attending on so dire a project. For what, alas,',
#   'ropension, and cut of All fears attending on so dire a project. For what, alas, ',
#   'opension, and cut of All fears attending on so dire a project. For what, alas, c',
#   'pension, and cut of All fears attending on so dire a project. For what, alas, ca',
#   'ension, and cut of All fears attending on so dire a project. For what, alas, can',
#   'nsion, and cut of All fears attending on so dire a project. For what, alas, can ',
#   'sion, and cut of All fears attending on so dire a project. For what, alas, can t',
#   'ion, and cut of All fears attending on so dire a project. For what, alas, can th',
#   'on, and cut of All fears attending on so dire a project. For what, alas, can the',
#   'n, and cut of All fears attending on so dire a project. For what, alas, can thes',
#   ', and cut of All fears attending on so dire a project. For what, alas, can these',
#   ' and cut of All fears attending on so dire a project. For what, alas, can these ',
#   'and cut of All fears attending on so dire a project. For what, alas, can these m',
#   'nd cut of All fears attending on so dire a project. For what, alas, can these my',
#   'd cut of All fears attending on so dire a project. For what, alas, can these my ',
#   ' cut of All fears attending on so dire a project. For what, alas, can these my s',
#   'cut of All fears attending on so dire a project. For what, alas, can these my si',
#   'ut of All fears attending on so dire a project. For what, alas, can these my sin',
#   't of All fears attending on so dire a project. For what, alas, can these my sing',
#   ' of All fears attending on so dire a project. For what, alas, can these my singl',
#   'of All fears attending on so dire a project. For what, alas, can these my single',
#   'f All fears attending on so dire a project. For what, alas, can these my single ',
#   ' All fears attending on so dire a project. For what, alas, can these my single a',
#   'All fears attending on so dire a project. For what, alas, can these my single ar',
#   'll fears attending on so dire a project. For what, alas, can these my single arm',
#   'l fears attending on so dire a project. For what, alas, can these my single arms',
#   ' fears attending on so dire a project. For what, alas, can these my single arms?',
#   'fears attending on so dire a project. For what, alas, can these my single arms? ',
#   'ears attending on so dire a project. For what, alas, can these my single arms? W',
#   'ars attending on so dire a project. For what, alas, can these my single arms? Wh',
#   'rs attending on so dire a project. For what, alas, can these my single arms? Wha',
#   's attending on so dire a project. For what, alas, can these my single arms? What',
#   ' attending on so dire a project. For what, alas, can these my single arms? What ',
#   'attending on so dire a project. For what, alas, can these my single arms? What p',
#   'ttending on so dire a project. For what, alas, can these my single arms? What pr',
#   'tending on so dire a project. For what, alas, can these my single arms? What pro',
#   'ending on so dire a project. For what, alas, can these my single arms? What prop',
#   'nding on so dire a project. For what, alas, can these my single arms? What propu',
#   'ding on so dire a project. For what, alas, can these my single arms? What propug',
#   'ing on so dire a project. For what, alas, can these my single arms? What propugn',
#   'ng on so dire a project. For what, alas, can these my single arms? What propugna',
#   'g on so dire a project. For what, alas, can these my single arms? What propugnat',
#   ' on so dire a project. For what, alas, can these my single arms? What propugnati',
#   'on so dire a project. For what, alas, can these my single arms? What propugnatio',
#   'n so dire a project. For what, alas, can these my single arms? What propugnation',
#   ' so dire a project. For what, alas, can these my single arms? What propugnation ',
#   'so dire a project. For what, alas, can these my single arms? What propugnation i',
#   'o dire a project. For what, alas, can these my single arms? What propugnation is',
#   ' dire a project. For what, alas, can these my single arms? What propugnation is ',
#   'dire a project. For what, alas, can these my single arms? What propugnation is i',
#   'ire a project. For what, alas, can these my single arms? What propugnation is in',
#   're a project. For what, alas, can these my single arms? What propugnation is in ',
#   'e a project. For what, alas, can these my single arms? What propugnation is in o',
#   ' a project. For what, alas, can these my single arms? What propugnation is in on',
#   'a project. For what, alas, can these my single arms? What propugnation is in one',
#   ' project. For what, alas, can these my single arms? What propugnation is in one ',
#   'project. For what, alas, can these my single arms? What propugnation is in one m',
#   'roject. For what, alas, can these my single arms? What propugnation is in one ma',
#   'oject. For what, alas, can these my single arms? What propugnation is in one man',
#   "ject. For what, alas, can these my single arms? What propugnation is in one man'",
#   "ect. For what, alas, can these my single arms? What propugnation is in one man's",
#   "ct. For what, alas, can these my single arms? What propugnation is in one man's ",
#   "t. For what, alas, can these my single arms? What propugnation is in one man's v",
#   ". For what, alas, can these my single arms? What propugnation is in one man's va",
#   " For what, alas, can these my single arms? What propugnation is in one man's val",
#   "For what, alas, can these my single arms? What propugnation is in one man's valo",
#   "or what, alas, can these my single arms? What propugnation is in one man's valou",
#   "r what, alas, can these my single arms? What propugnation is in one man's valour",
#   " what, alas, can these my single arms? What propugnation is in one man's valour ",
#   "what, alas, can these my single arms? What propugnation is in one man's valour T",
#   "hat, alas, can these my single arms? What propugnation is in one man's valour To",
#   "at, alas, can these my single arms? What propugnation is in one man's valour To ",
#   "t, alas, can these my single arms? What propugnation is in one man's valour To s",
#   ", alas, can these my single arms? What propugnation is in one man's valour To st",
#   " alas, can these my single arms? What propugnation is in one man's valour To sta",
#   "alas, can these my single arms? What propugnation is in one man's valour To stan",
#   "las, can these my single arms? What propugnation is in one man's valour To stand",
#   "as, can these my single arms? What propugnation is in one man's valour To stand ",
#   "s, can these my single arms? What propugnation is in one man's valour To stand t",
#   ", can these my single arms? What propugnation is in one man's valour To stand th",
#   " can these my single arms? What propugnation is in one man's valour To stand the",
#   "can these my single arms? What propugnation is in one man's valour To stand the ",
#   "an these my single arms? What propugnation is in one man's valour To stand the p",
#   "n these my single arms? What propugnation is in one man's valour To stand the pu",
#   " these my single arms? What propugnation is in one man's valour To stand the pus",
#   "these my single arms? What propugnation is in one man's valour To stand the push",
#   "hese my single arms? What propugnation is in one man's valour To stand the push ",
#   "ese my single arms? What propugnation is in one man's valour To stand the push a",
#   "se my single arms? What propugnation is in one man's valour To stand the push an",
#   "e my single arms? What propugnation is in one man's valour To stand the push and",
#   " my single arms? What propugnation is in one man's valour To stand the push and ",
#   "my single arms? What propugnation is in one man's valour To stand the push and e",
#   "y single arms? What propugnation is in one man's valour To stand the push and en",
#   " single arms? What propugnation is in one man's valour To stand the push and enm",
#   "single arms? What propugnation is in one man's valour To stand the push and enmi",
#   "ingle arms? What propugnation is in one man's valour To stand the push and enmit",
#   "ngle arms? What propugnation is in one man's valour To stand the push and enmity",
#   "gle arms? What propugnation is in one man's valour To stand the push and enmity ",
#   "le arms? What propugnation is in one man's valour To stand the push and enmity o",
#   "e arms? What propugnation is in one man's valour To stand the push and enmity of",
#   " arms? What propugnation is in one man's valour To stand the push and enmity of ",
#   "arms? What propugnation is in one man's valour To stand the push and enmity of t",
#   "rms? What propugnation is in one man's valour To stand the push and enmity of th",
#   "ms? What propugnation is in one man's valour To stand the push and enmity of tho",
#   "s? What propugnation is in one man's valour To stand the push and enmity of thos",
#   "? What propugnation is in one man's valour To stand the push and enmity of those",
#   " What propugnation is in one man's valour To stand the push and enmity of those ",
#   "What propugnation is in one man's valour To stand the push and enmity of those T",
#   "hat propugnation is in one man's valour To stand the push and enmity of those Th",
#   "at propugnation is in one man's valour To stand the push and enmity of those Thi",
#   "t propugnation is in one man's valour To stand the push and enmity of those This",
#   " propugnation is in one man's valour To stand the push and enmity of those This ",
#   "propugnation is in one man's valour To stand the push and enmity of those This q",
#   "ropugnation is in one man's valour To stand the push and enmity of those This qu",
#   "opugnation is in one man's valour To stand the push and enmity of those This qua",
#   "pugnation is in one man's valour To stand the push and enmity of those This quar",
#   "ugnation is in one man's valour To stand the push and enmity of those This quarr",
#   "gnation is in one man's valour To stand the push and enmity of those This quarre",
#   "nation is in one man's valour To stand the push and enmity of those This quarrel",
#   "ation is in one man's valour To stand the push and enmity of those This quarrel ",
#   "tion is in one man's valour To stand the push and enmity of those This quarrel w",
#   "ion is in one man's valour To stand the push and enmity of those This quarrel wo",
#   "on is in one man's valour To stand the push and enmity of those This quarrel wou",
#   "n is in one man's valour To stand the push and enmity of those This quarrel woul",
#   " is in one man's valour To stand the push and enmity of those This quarrel would",
#   "is in one man's valour To stand the push and enmity of those This quarrel would ",
#   "s in one man's valour To stand the push and enmity of those This quarrel would e",
#   " in one man's valour To stand the push and enmity of those This quarrel would ex",
#   "in one man's valour To stand the push and enmity of those This quarrel would exc",
#   "n one man's valour To stand the push and enmity of those This quarrel would exci",
#   " one man's valour To stand the push and enmity of those This quarrel would excit",
#   "one man's valour To stand the push and enmity of those This quarrel would excite",
#   "ne man's valour To stand the push and enmity of those This quarrel would excite?",
#   "e man's valour To stand the push and enmity of those This quarrel would excite? ",
#   " man's valour To stand the push and enmity of those This quarrel would excite? Y",
#   "man's valour To stand the push and enmity of those This quarrel would excite? Ye",
#   "an's valour To stand the push and enmity of those This quarrel would excite? Yet",
#   "n's valour To stand the push and enmity of those This quarrel would excite? Yet,",
#   "'s valour To stand the push and enmity of those This quarrel would excite? Yet, ",
#   's valour To stand the push and enmity of those This quarrel would excite? Yet, I',
#   ' valour To stand the push and enmity of those This quarrel would excite? Yet, I ',
#   'valour To stand the push and enmity of those This quarrel would excite? Yet, I p',
#   'alour To stand the push and enmity of those This quarrel would excite? Yet, I pr',
#   'lour To stand the push and enmity of those This quarrel would excite? Yet, I pro',
#   'our To stand the push and enmity of those This quarrel would excite? Yet, I prot',
#   'ur To stand the push and enmity of those This quarrel would excite? Yet, I prote',
#   'r To stand the push and enmity of those This quarrel would excite? Yet, I protes',
#   ' To stand the push and enmity of those This quarrel would excite? Yet, I protest',
#   'To stand the push and enmity of those This quarrel would excite? Yet, I protest,',
#   'o stand the push and enmity of those This quarrel would excite? Yet, I protest, ',
#   ' stand the push and enmity of those This quarrel would excite? Yet, I protest, W',
#   'stand the push and enmity of those This quarrel would excite? Yet, I protest, We',
#   'tand the push and enmity of those This quarrel would excite? Yet, I protest, Wer',
#   'and the push and enmity of those This quarrel would excite? Yet, I protest, Were',
#   'nd the push and enmity of those This quarrel would excite? Yet, I protest, Were ',
#   'd the push and enmity of those This quarrel would excite? Yet, I protest, Were I',
#   ' the push and enmity of those This quarrel would excite? Yet, I protest, Were I ',
#   'the push and enmity of those This quarrel would excite? Yet, I protest, Were I a',
#   'he push and enmity of those This quarrel would excite? Yet, I protest, Were I al',
#   'e push and enmity of those This quarrel would excite? Yet, I protest, Were I alo',
#   ' push and enmity of those This quarrel would excite? Yet, I protest, Were I alon',
#   'push and enmity of those This quarrel would excite? Yet, I protest, Were I alone',
#   'ush and enmity of those This quarrel would excite? Yet, I protest, Were I alone ',
#   'sh and enmity of those This quarrel would excite? Yet, I protest, Were I alone t',
#   'h and enmity of those This quarrel would excite? Yet, I protest, Were I alone to',
#   ' and enmity of those This quarrel would excite? Yet, I protest, Were I alone to ',
#   'and enmity of those This quarrel would excite? Yet, I protest, Were I alone to p',
#   'nd enmity of those This quarrel would excite? Yet, I protest, Were I alone to pa',
#   'd enmity of those This quarrel would excite? Yet, I protest, Were I alone to pas',
#   ' enmity of those This quarrel would excite? Yet, I protest, Were I alone to pass',
#   'enmity of those This quarrel would excite? Yet, I protest, Were I alone to pass ',
#   'nmity of those This quarrel would excite? Yet, I protest, Were I alone to pass t',
#   'mity of those This quarrel would excite? Yet, I protest, Were I alone to pass th',
#   'ity of those This quarrel would excite? Yet, I protest, Were I alone to pass the',
#   'ty of those This quarrel would excite? Yet, I protest, Were I alone to pass the ',
#   'y of those This quarrel would excite? Yet, I protest, Were I alone to pass the d',
#   ' of those This quarrel would excite? Yet, I protest, Were I alone to pass the di',
#   'of those This quarrel would excite? Yet, I protest, Were I alone to pass the dif',
#   'f those This quarrel would excite? Yet, I protest, Were I alone to pass the diff',
#   ' those This quarrel would excite? Yet, I protest, Were I alone to pass the diffi',
#   'those This quarrel would excite? Yet, I protest, Were I alone to pass the diffic',
#   'hose This quarrel would excite? Yet, I protest, Were I alone to pass the difficu',
#   'ose This quarrel would excite? Yet, I protest, Were I alone to pass the difficul',
#   'se This quarrel would excite? Yet, I protest, Were I alone to pass the difficult',
#   'e This quarrel would excite? Yet, I protest, Were I alone to pass the difficulti',
#   ' This quarrel would excite? Yet, I protest, Were I alone to pass the difficultie',
#   'This quarrel would excite? Yet, I protest, Were I alone to pass the difficulties',
#   'his quarrel would excite? Yet, I protest, Were I alone to pass the difficulties,',
#   'is quarrel would excite? Yet, I protest, Were I alone to pass the difficulties, ',
#   's quarrel would excite? Yet, I protest, Were I alone to pass the difficulties, A',
#   ' quarrel would excite? Yet, I protest, Were I alone to pass the difficulties, An',
#   'quarrel would excite? Yet, I protest, Were I alone to pass the difficulties, And',
#   'uarrel would excite? Yet, I protest, Were I alone to pass the difficulties, And ',
#   'arrel would excite? Yet, I protest, Were I alone to pass the difficulties, And h',
#   'rrel would excite? Yet, I protest, Were I alone to pass the difficulties, And ha',
#   'rel would excite? Yet, I protest, Were I alone to pass the difficulties, And had',
#   'el would excite? Yet, I protest, Were I alone to pass the difficulties, And had ',
#   'l would excite? Yet, I protest, Were I alone to pass the difficulties, And had a',
#   ' would excite? Yet, I protest, Were I alone to pass the difficulties, And had as',
#   'would excite? Yet, I protest, Were I alone to pass the difficulties, And had as ',
#   'ould excite? Yet, I protest, Were I alone to pass the difficulties, And had as a',
#   'uld excite? Yet, I protest, Were I alone to pass the difficulties, And had as am',
#   'ld excite? Yet, I protest, Were I alone to pass the difficulties, And had as amp',
#   'd excite? Yet, I protest, Were I alone to pass the difficulties, And had as ampl',
#   ' excite? Yet, I protest, Were I alone to pass the difficulties, And had as ample',
#   'excite? Yet, I protest, Were I alone to pass the difficulties, And had as ample ',
#   'xcite? Yet, I protest, Were I alone to pass the difficulties, And had as ample p',
#   'cite? Yet, I protest, Were I alone to pass the difficulties, And had as ample po',
#   'ite? Yet, I protest, Were I alone to pass the difficulties, And had as ample pow',
#   'te? Yet, I protest, Were I alone to pass the difficulties, And had as ample powe',
#   'e? Yet, I protest, Were I alone to pass the difficulties, And had as ample power',
#   '? Yet, I protest, Were I alone to pass the difficulties, And had as ample power ',
#   ' Yet, I protest, Were I alone to pass the difficulties, And had as ample power a',
#   'Yet, I protest, Were I alone to pass the difficulties, And had as ample power as',
#   'et, I protest, Were I alone to pass the difficulties, And had as ample power as ',
#   't, I protest, Were I alone to pass the difficulties, And had as ample power as I',
#   ', I protest, Were I alone to pass the difficulties, And had as ample power as I ',
#   ' I protest, Were I alone to pass the difficulties, And had as ample power as I h',
#   'I protest, Were I alone to pass the difficulties, And had as ample power as I ha',
#   ' protest, Were I alone to pass the difficulties, And had as ample power as I hav',
#   'protest, Were I alone to pass the difficulties, And had as ample power as I have',
#   'rotest, Were I alone to pass the difficulties, And had as ample power as I have ',
#   'otest, Were I alone to pass the difficulties, And had as ample power as I have w',
#   'test, Were I alone to pass the difficulties, And had as ample power as I have wi',
#   'est, Were I alone to pass the difficulties, And had as ample power as I have wil',
#   'st, Were I alone to pass the difficulties, And had as ample power as I have will',
#   't, Were I alone to pass the difficulties, And had as ample power as I have will,',
#   ', Were I alone to pass the difficulties, And had as ample power as I have will, ',
#   ' Were I alone to pass the difficulties, And had as ample power as I have will, P',
#   'Were I alone to pass the difficulties, And had as ample power as I have will, Pa',
#   'ere I alone to pass the difficulties, And had as ample power as I have will, Par',
#   're I alone to pass the difficulties, And had as ample power as I have will, Pari',
#   'e I alone to pass the difficulties, And had as ample power as I have will, Paris',
#   ' I alone to pass the difficulties, And had as ample power as I have will, Paris ',
#   'I alone to pass the difficulties, And had as ample power as I have will, Paris s',
#   ' alone to pass the difficulties, And had as ample power as I have will, Paris sh',
#   'alone to pass the difficulties, And had as ample power as I have will, Paris sho',
#   'lone to pass the difficulties, And had as ample power as I have will, Paris shou',
#   'one to pass the difficulties, And had as ample power as I have will, Paris shoul',
#   'ne to pass the difficulties, And had as ample power as I have will, Paris should',
#   'e to pass the difficulties, And had as ample power as I have will, Paris should ',
#   ' to pass the difficulties, And had as ample power as I have will, Paris should n',
#   'to pass the difficulties, And had as ample power as I have will, Paris should ne',
#   "o pass the difficulties, And had as ample power as I have will, Paris should ne'",
#   " pass the difficulties, And had as ample power as I have will, Paris should ne'e",
#   "pass the difficulties, And had as ample power as I have will, Paris should ne'er",
#   "ass the difficulties, And had as ample power as I have will, Paris should ne'er ",
#   "ss the difficulties, And had as ample power as I have will, Paris should ne'er r",
#   "s the difficulties, And had as ample power as I have will, Paris should ne'er re",
#   " the difficulties, And had as ample power as I have will, Paris should ne'er ret",
#   "the difficulties, And had as ample power as I have will, Paris should ne'er retr",
#   "he difficulties, And had as ample power as I have will, Paris should ne'er retra",
#   "e difficulties, And had as ample power as I have will, Paris should ne'er retrac",
#   " difficulties, And had as ample power as I have will, Paris should ne'er retract",
#   "difficulties, And had as ample power as I have will, Paris should ne'er retract ",
#   "ifficulties, And had as ample power as I have will, Paris should ne'er retract w",
#   "fficulties, And had as ample power as I have will, Paris should ne'er retract wh",
#   "ficulties, And had as ample power as I have will, Paris should ne'er retract wha",
#   "iculties, And had as ample power as I have will, Paris should ne'er retract what",
#   "culties, And had as ample power as I have will, Paris should ne'er retract what ",
#   "ulties, And had as ample power as I have will, Paris should ne'er retract what h",
#   "lties, And had as ample power as I have will, Paris should ne'er retract what he",
#   "ties, And had as ample power as I have will, Paris should ne'er retract what he ",
#   "ies, And had as ample power as I have will, Paris should ne'er retract what he h",
#   "es, And had as ample power as I have will, Paris should ne'er retract what he ha",
#   "s, And had as ample power as I have will, Paris should ne'er retract what he hat",
#   ", And had as ample power as I have will, Paris should ne'er retract what he hath",
#   " And had as ample power as I have will, Paris should ne'er retract what he hath ",
#   "And had as ample power as I have will, Paris should ne'er retract what he hath d",
#   "nd had as ample power as I have will, Paris should ne'er retract what he hath do",
#   "d had as ample power as I have will, Paris should ne'er retract what he hath don",
#   " had as ample power as I have will, Paris should ne'er retract what he hath done",
#   "had as ample power as I have will, Paris should ne'er retract what he hath done ",
#   "ad as ample power as I have will, Paris should ne'er retract what he hath done N",
#   "d as ample power as I have will, Paris should ne'er retract what he hath done No",
#   " as ample power as I have will, Paris should ne'er retract what he hath done Nor",
#   "as ample power as I have will, Paris should ne'er retract what he hath done Nor ",
#   "s ample power as I have will, Paris should ne'er retract what he hath done Nor f",
#   " ample power as I have will, Paris should ne'er retract what he hath done Nor fa",
#   "ample power as I have will, Paris should ne'er retract what he hath done Nor fai",
#   "mple power as I have will, Paris should ne'er retract what he hath done Nor fain",
#   "ple power as I have will, Paris should ne'er retract what he hath done Nor faint",
#   "le power as I have will, Paris should ne'er retract what he hath done Nor faint ",
#   "e power as I have will, Paris should ne'er retract what he hath done Nor faint i",
#   " power as I have will, Paris should ne'er retract what he hath done Nor faint in",
#   "power as I have will, Paris should ne'er retract what he hath done Nor faint in ",
#   "ower as I have will, Paris should ne'er retract what he hath done Nor faint in t",
#   "wer as I have will, Paris should ne'er retract what he hath done Nor faint in th",
#   "er as I have will, Paris should ne'er retract what he hath done Nor faint in the",
#   "r as I have will, Paris should ne'er retract what he hath done Nor faint in the ",
#   " as I have will, Paris should ne'er retract what he hath done Nor faint in the p",
#   "as I have will, Paris should ne'er retract what he hath done Nor faint in the pu",
#   "s I have will, Paris should ne'er retract what he hath done Nor faint in the pur",
#   " I have will, Paris should ne'er retract what he hath done Nor faint in the purs",
#   "I have will, Paris should ne'er retract what he hath done Nor faint in the pursu",
#   " have will, Paris should ne'er retract what he hath done Nor faint in the pursui",
#   "have will, Paris should ne'er retract what he hath done Nor faint in the pursuit",
#   "ave will, Paris should ne'er retract what he hath done Nor faint in the pursuit.",
#   "ve will, Paris should ne'er retract what he hath done Nor faint in the pursuit. ",
#   "e will, Paris should ne'er retract what he hath done Nor faint in the pursuit. S",
#   " will, Paris should ne'er retract what he hath done Nor faint in the pursuit. Si",
#   "will, Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir",
#   "ill, Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir,",
#   "ll, Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir, ",
#   "l, Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I",
#   ", Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I ",
#   " Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I p",
#   "Paris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I pr",
#   "aris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I pro",
#   "ris should ne'er retract what he hath done Nor faint in the pursuit. Sir, I prop",
#   "is should ne'er retract what he hath done Nor faint in the pursuit. Sir, I propo",
#   "s should ne'er retract what he hath done Nor faint in the pursuit. Sir, I propos",
#   " should ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose",
#   "should ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose ",
#   "hould ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose n",
#   "ould ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose no",
#   "uld ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose not",
#   "ld ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose not ",
#   "d ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose not m",
#   " ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose not me",
#   "ne'er retract what he hath done Nor faint in the pursuit. Sir, I propose not mer",
#   "e'er retract what he hath done Nor faint in the pursuit. Sir, I propose not mere",
#   "'er retract what he hath done Nor faint in the pursuit. Sir, I propose not merel",
#   'er retract what he hath done Nor faint in the pursuit. Sir, I propose not merely',
#   'r retract what he hath done Nor faint in the pursuit. Sir, I propose not merely ',
#   ' retract what he hath done Nor faint in the pursuit. Sir, I propose not merely t',
#   'retract what he hath done Nor faint in the pursuit. Sir, I propose not merely to',
#   'etract what he hath done Nor faint in the pursuit. Sir, I propose not merely to ',
#   'tract what he hath done Nor faint in the pursuit. Sir, I propose not merely to m',
#   'ract what he hath done Nor faint in the pursuit. Sir, I propose not merely to my',
#   'act what he hath done Nor faint in the pursuit. Sir, I propose not merely to mys',
#   'ct what he hath done Nor faint in the pursuit. Sir, I propose not merely to myse',
#   't what he hath done Nor faint in the pursuit. Sir, I propose not merely to mysel',
#   ' what he hath done Nor faint in the pursuit. Sir, I propose not merely to myself',
#   'what he hath done Nor faint in the pursuit. Sir, I propose not merely to myself ',
#   'hat he hath done Nor faint in the pursuit. Sir, I propose not merely to myself T',
#   'at he hath done Nor faint in the pursuit. Sir, I propose not merely to myself Th',
#   't he hath done Nor faint in the pursuit. Sir, I propose not merely to myself The',
#   ' he hath done Nor faint in the pursuit. Sir, I propose not merely to myself The ',
#   'he hath done Nor faint in the pursuit. Sir, I propose not merely to myself The p',
#   'e hath done Nor faint in the pursuit. Sir, I propose not merely to myself The pl',
#   ' hath done Nor faint in the pursuit. Sir, I propose not merely to myself The ple',
#   'hath done Nor faint in the pursuit. Sir, I propose not merely to myself The plea',
#   'ath done Nor faint in the pursuit. Sir, I propose not merely to myself The pleas',
#   'th done Nor faint in the pursuit. Sir, I propose not merely to myself The pleasu',
#   'h done Nor faint in the pursuit. Sir, I propose not merely to myself The pleasur',
#   ' done Nor faint in the pursuit. Sir, I propose not merely to myself The pleasure',
#   'done Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures',
#   'one Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures ',
#   'ne Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures s',
#   'e Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures su',
#   ' Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures suc',
#   'Nor faint in the pursuit. Sir, I propose not merely to myself The pleasures such',
#   'or faint in the pursuit. Sir, I propose not merely to myself The pleasures such ',
#   'r faint in the pursuit. Sir, I propose not merely to myself The pleasures such a',
#   ' faint in the pursuit. Sir, I propose not merely to myself The pleasures such a ',
#   'faint in the pursuit. Sir, I propose not merely to myself The pleasures such a b',
#   'aint in the pursuit. Sir, I propose not merely to myself The pleasures such a be',
#   'int in the pursuit. Sir, I propose not merely to myself The pleasures such a bea',
#   'nt in the pursuit. Sir, I propose not merely to myself The pleasures such a beau',
#   't in the pursuit. Sir, I propose not merely to myself The pleasures such a beaut',
#   ' in the pursuit. Sir, I propose not merely to myself The pleasures such a beauty',
#   'in the pursuit. Sir, I propose not merely to myself The pleasures such a beauty ',
#   'n the pursuit. Sir, I propose not merely to myself The pleasures such a beauty b',
#   ' the pursuit. Sir, I propose not merely to myself The pleasures such a beauty br',
#   'the pursuit. Sir, I propose not merely to myself The pleasures such a beauty bri',
#   'he pursuit. Sir, I propose not merely to myself The pleasures such a beauty brin',
#   'e pursuit. Sir, I propose not merely to myself The pleasures such a beauty bring',
#   ' pursuit. Sir, I propose not merely to myself The pleasures such a beauty brings',
#   'pursuit. Sir, I propose not merely to myself The pleasures such a beauty brings ',
#   'ursuit. Sir, I propose not merely to myself The pleasures such a beauty brings w',
#   'rsuit. Sir, I propose not merely to myself The pleasures such a beauty brings wi',
#   'suit. Sir, I propose not merely to myself The pleasures such a beauty brings wit',
#   'uit. Sir, I propose not merely to myself The pleasures such a beauty brings with',
#   'it. Sir, I propose not merely to myself The pleasures such a beauty brings with ',
#   't. Sir, I propose not merely to myself The pleasures such a beauty brings with i',
#   '. Sir, I propose not merely to myself The pleasures such a beauty brings with it',
#   ' Sir, I propose not merely to myself The pleasures such a beauty brings with it;',
#   'Sir, I propose not merely to myself The pleasures such a beauty brings with it; ',
#   'ir, I propose not merely to myself The pleasures such a beauty brings with it; B',
#   'r, I propose not merely to myself The pleasures such a beauty brings with it; Bu',
#   ', I propose not merely to myself The pleasures such a beauty brings with it; But',
#   ' I propose not merely to myself The pleasures such a beauty brings with it; But ',
#   'I propose not merely to myself The pleasures such a beauty brings with it; But I',
#   ' propose not merely to myself The pleasures such a beauty brings with it; But I ',
#   'propose not merely to myself The pleasures such a beauty brings with it; But I w',
#   'ropose not merely to myself The pleasures such a beauty brings with it; But I wo',
#   'opose not merely to myself The pleasures such a beauty brings with it; But I wou',
#   'pose not merely to myself The pleasures such a beauty brings with it; But I woul',
#   'ose not merely to myself The pleasures such a beauty brings with it; But I would',
#   'se not merely to myself The pleasures such a beauty brings with it; But I would ',
#   'e not merely to myself The pleasures such a beauty brings with it; But I would h',
#   ' not merely to myself The pleasures such a beauty brings with it; But I would ha',
#   'not merely to myself The pleasures such a beauty brings with it; But I would hav',
#   'ot merely to myself The pleasures such a beauty brings with it; But I would have',
#   't merely to myself The pleasures such a beauty brings with it; But I would have ',
#   ' merely to myself The pleasures such a beauty brings with it; But I would have t',
#   'merely to myself The pleasures such a beauty brings with it; But I would have th',
#   'erely to myself The pleasures such a beauty brings with it; But I would have the',
#   'rely to myself The pleasures such a beauty brings with it; But I would have the ',
#   'ely to myself The pleasures such a beauty brings with it; But I would have the s',
#   'ly to myself The pleasures such a beauty brings with it; But I would have the so',
#   'y to myself The pleasures such a beauty brings with it; But I would have the soi',
#   ' to myself The pleasures such a beauty brings with it; But I would have the soil',
#   'to myself The pleasures such a beauty brings with it; But I would have the soil ',
#   'o myself The pleasures such a beauty brings with it; But I would have the soil o',
#   ' myself The pleasures such a beauty brings with it; But I would have the soil of',
#   'myself The pleasures such a beauty brings with it; But I would have the soil of ',
#   'yself The pleasures such a beauty brings with it; But I would have the soil of h',
#   'self The pleasures such a beauty brings with it; But I would have the soil of he',
#   'elf The pleasures such a beauty brings with it; But I would have the soil of her',
#   'lf The pleasures such a beauty brings with it; But I would have the soil of her ',
#   'f The pleasures such a beauty brings with it; But I would have the soil of her f',
#   ' The pleasures such a beauty brings with it; But I would have the soil of her fa',
#   'The pleasures such a beauty brings with it; But I would have the soil of her fai',
#   'he pleasures such a beauty brings with it; But I would have the soil of her fair',
#   'e pleasures such a beauty brings with it; But I would have the soil of her fair ',
# ...
#   "ooting in your generous bosoms? There's not the meanest spirit on our party With",
#   "oting in your generous bosoms? There's not the meanest spirit on our party Witho",
#   "ting in your generous bosoms? There's not the meanest spirit on our party Withou",
#   "ing in your generous bosoms? There's not the meanest spirit on our party Without",
#   "ng in your generous bosoms? There's not the meanest spirit on our party Without ",
#   "g in your generous bosoms? There's not the meanest spirit on our party Without a",
#   " in your generous bosoms? There's not the meanest spirit on our party Without a ",
#   "in your generous bosoms? There's not the meanest spirit on our party Without a h",
#   "n your generous bosoms? There's not the meanest spirit on our party Without a he",
#   " your generous bosoms? There's not the meanest spirit on our party Without a hea",
#   "your generous bosoms? There's not the meanest spirit on our party Without a hear",
#   "our generous bosoms? There's not the meanest spirit on our party Without a heart",
#   "ur generous bosoms? There's not the meanest spirit on our party Without a heart ",
#   "r generous bosoms? There's not the meanest spirit on our party Without a heart t",
#   " generous bosoms? There's not the meanest spirit on our party Without a heart to",
#   "generous bosoms? There's not the meanest spirit on our party Without a heart to ",
#   "enerous bosoms? There's not the meanest spirit on our party Without a heart to d",
#   "nerous bosoms? There's not the meanest spirit on our party Without a heart to da",
#   "erous bosoms? There's not the meanest spirit on our party Without a heart to dar",
#   "rous bosoms? There's not the meanest spirit on our party Without a heart to dare",
#   "ous bosoms? There's not the meanest spirit on our party Without a heart to dare ",
#   "us bosoms? There's not the meanest spirit on our party Without a heart to dare o",
#   "s bosoms? There's not the meanest spirit on our party Without a heart to dare or",
#   " bosoms? There's not the meanest spirit on our party Without a heart to dare or ",
#   "bosoms? There's not the meanest spirit on our party Without a heart to dare or s",
#   "osoms? There's not the meanest spirit on our party Without a heart to dare or sw",
#   "soms? There's not the meanest spirit on our party Without a heart to dare or swo",
#   "oms? There's not the meanest spirit on our party Without a heart to dare or swor",
#   "ms? There's not the meanest spirit on our party Without a heart to dare or sword",
#   "s? There's not the meanest spirit on our party Without a heart to dare or sword ",
#   "? There's not the meanest spirit on our party Without a heart to dare or sword t",
#   " There's not the meanest spirit on our party Without a heart to dare or sword to",
#   "There's not the meanest spirit on our party Without a heart to dare or sword to ",
#   "here's not the meanest spirit on our party Without a heart to dare or sword to d",
#   "ere's not the meanest spirit on our party Without a heart to dare or sword to dr",
#   "re's not the meanest spirit on our party Without a heart to dare or sword to dra",
#   "e's not the meanest spirit on our party Without a heart to dare or sword to draw",
#   "'s not the meanest spirit on our party Without a heart to dare or sword to draw ",
#   's not the meanest spirit on our party Without a heart to dare or sword to draw W',
#   ' not the meanest spirit on our party Without a heart to dare or sword to draw Wh',
#   'not the meanest spirit on our party Without a heart to dare or sword to draw Whe',
#   'ot the meanest spirit on our party Without a heart to dare or sword to draw When',
#   't the meanest spirit on our party Without a heart to dare or sword to draw When ',
#   ' the meanest spirit on our party Without a heart to dare or sword to draw When H',
#   'the meanest spirit on our party Without a heart to dare or sword to draw When He',
#   'he meanest spirit on our party Without a heart to dare or sword to draw When Hel',
#   'e meanest spirit on our party Without a heart to dare or sword to draw When Hele',
#   ' meanest spirit on our party Without a heart to dare or sword to draw When Helen',
#   'meanest spirit on our party Without a heart to dare or sword to draw When Helen ',
#   'eanest spirit on our party Without a heart to dare or sword to draw When Helen i',
#   'anest spirit on our party Without a heart to dare or sword to draw When Helen is',
#   'nest spirit on our party Without a heart to dare or sword to draw When Helen is ',
#   'est spirit on our party Without a heart to dare or sword to draw When Helen is d',
#   'st spirit on our party Without a heart to dare or sword to draw When Helen is de',
#   't spirit on our party Without a heart to dare or sword to draw When Helen is def',
#   ' spirit on our party Without a heart to dare or sword to draw When Helen is defe',
#   'spirit on our party Without a heart to dare or sword to draw When Helen is defen',
#   'pirit on our party Without a heart to dare or sword to draw When Helen is defend',
#   'irit on our party Without a heart to dare or sword to draw When Helen is defende',
#   'rit on our party Without a heart to dare or sword to draw When Helen is defended',
#   'it on our party Without a heart to dare or sword to draw When Helen is defended;',
#   't on our party Without a heart to dare or sword to draw When Helen is defended; ',
#   ' on our party Without a heart to dare or sword to draw When Helen is defended; n',
#   'on our party Without a heart to dare or sword to draw When Helen is defended; no',
#   'n our party Without a heart to dare or sword to draw When Helen is defended; nor',
#   ' our party Without a heart to dare or sword to draw When Helen is defended; nor ',
#   'our party Without a heart to dare or sword to draw When Helen is defended; nor n',
#   'ur party Without a heart to dare or sword to draw When Helen is defended; nor no',
#   'r party Without a heart to dare or sword to draw When Helen is defended; nor non',
#   ' party Without a heart to dare or sword to draw When Helen is defended; nor none',
#   'party Without a heart to dare or sword to draw When Helen is defended; nor none ',
#   'arty Without a heart to dare or sword to draw When Helen is defended; nor none s',
#   'rty Without a heart to dare or sword to draw When Helen is defended; nor none so',
#   'ty Without a heart to dare or sword to draw When Helen is defended; nor none so ',
#   'y Without a heart to dare or sword to draw When Helen is defended; nor none so n',
#   ' Without a heart to dare or sword to draw When Helen is defended; nor none so no',
#   'Without a heart to dare or sword to draw When Helen is defended; nor none so nob',
#   'ithout a heart to dare or sword to draw When Helen is defended; nor none so nobl',
#   'thout a heart to dare or sword to draw When Helen is defended; nor none so noble',
#   'hout a heart to dare or sword to draw When Helen is defended; nor none so noble ',
#   'out a heart to dare or sword to draw When Helen is defended; nor none so noble W',
#   'ut a heart to dare or sword to draw When Helen is defended; nor none so noble Wh',
#   't a heart to dare or sword to draw When Helen is defended; nor none so noble Who',
#   ' a heart to dare or sword to draw When Helen is defended; nor none so noble Whos',
#   'a heart to dare or sword to draw When Helen is defended; nor none so noble Whose',
#   ' heart to dare or sword to draw When Helen is defended; nor none so noble Whose ',
#   'heart to dare or sword to draw When Helen is defended; nor none so noble Whose l',
#   'eart to dare or sword to draw When Helen is defended; nor none so noble Whose li',
#   'art to dare or sword to draw When Helen is defended; nor none so noble Whose lif',
#   'rt to dare or sword to draw When Helen is defended; nor none so noble Whose life',
#   't to dare or sword to draw When Helen is defended; nor none so noble Whose life ',
#   ' to dare or sword to draw When Helen is defended; nor none so noble Whose life w',
#   'to dare or sword to draw When Helen is defended; nor none so noble Whose life we',
#   'o dare or sword to draw When Helen is defended; nor none so noble Whose life wer',
#   ' dare or sword to draw When Helen is defended; nor none so noble Whose life were',
#   'dare or sword to draw When Helen is defended; nor none so noble Whose life were ',
#   'are or sword to draw When Helen is defended; nor none so noble Whose life were i',
#   're or sword to draw When Helen is defended; nor none so noble Whose life were il',
#   'e or sword to draw When Helen is defended; nor none so noble Whose life were ill',
#   ' or sword to draw When Helen is defended; nor none so noble Whose life were ill ',
#   'or sword to draw When Helen is defended; nor none so noble Whose life were ill b',
#   'r sword to draw When Helen is defended; nor none so noble Whose life were ill be',
#   ' sword to draw When Helen is defended; nor none so noble Whose life were ill bes',
#   'sword to draw When Helen is defended; nor none so noble Whose life were ill best',
#   ...],
#  'y': [';',
#   ' ',
#   'B',
#   'u',
#   't',
#   ' ',
#   'I',
#   ' ',
#   'a',
#   't',
#   't',
#   'e',
#   's',
#   't',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'g',
#   'o',
#   'd',
#   's',
#   ',',
#   ' ',
#   'y',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'f',
#   'u',
#   'l',
#   'l',
#   ' ',
#   'c',
#   'o',
#   'n',
#   's',
#   'e',
#   'n',
#   't',
#   ' ',
#   'G',
#   'a',
#   'v',
#   'e',
#   ' ',
#   'w',
#   'i',
#   'n',
#   'g',
#   's',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'm',
#   'y',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'p',
#   'e',
#   'n',
#   's',
#   'i',
#   'o',
#   'n',
#   ',',
#   ' ',
#   'a',
#   'n',
#   'd',
#   ' ',
#   'c',
#   'u',
#   't',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'A',
#   'l',
#   'l',
#   ' ',
#   'f',
#   'e',
#   'a',
#   'r',
#   's',
#   ' ',
#   'a',
#   't',
#   't',
#   'e',
#   'n',
#   'd',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   's',
#   'o',
#   ' ',
#   'd',
#   'i',
#   'r',
#   'e',
#   ' ',
#   'a',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'j',
#   'e',
#   'c',
#   't',
#   '.',
#   ' ',
#   'F',
#   'o',
#   'r',
#   ' ',
#   'w',
#   'h',
#   'a',
#   't',
#   ',',
#   ' ',
#   'a',
#   'l',
#   'a',
#   's',
#   ',',
#   ' ',
#   'c',
#   'a',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   's',
#   'e',
#   ' ',
#   'm',
#   'y',
#   ' ',
#   's',
#   'i',
#   'n',
#   'g',
#   'l',
#   'e',
#   ' ',
#   'a',
#   'r',
#   'm',
#   's',
#   '?',
#   ' ',
#   'W',
#   'h',
#   'a',
#   't',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'p',
#   'u',
#   'g',
#   'n',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'i',
#   's',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   'o',
#   'n',
#   'e',
#   ' ',
#   'm',
#   'a',
#   'n',
#   "'",
#   's',
#   ' ',
#   'v',
#   'a',
#   'l',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'T',
#   'o',
#   ' ',
#   's',
#   't',
#   'a',
#   'n',
#   'd',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'p',
#   'u',
#   's',
#   'h',
#   ' ',
#   'a',
#   'n',
#   'd',
#   ' ',
#   'e',
#   'n',
#   'm',
#   'i',
#   't',
#   'y',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   't',
#   'h',
#   'o',
#   's',
#   'e',
#   ' ',
#   'T',
#   'h',
#   'i',
#   's',
#   ' ',
#   'q',
#   'u',
#   'a',
#   'r',
#   'r',
#   'e',
#   'l',
#   ' ',
#   'w',
#   'o',
#   'u',
#   'l',
#   'd',
#   ' ',
#   'e',
#   'x',
#   'c',
#   'i',
#   't',
#   'e',
#   '?',
#   ' ',
#   'Y',
#   'e',
#   't',
#   ',',
#   ' ',
#   'I',
#   ' ',
#   'p',
#   'r',
#   'o',
#   't',
#   'e',
#   's',
#   't',
#   ',',
#   ' ',
#   'W',
#   'e',
#   'r',
#   'e',
#   ' ',
#   'I',
#   ' ',
#   'a',
#   'l',
#   'o',
#   'n',
#   'e',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'p',
#   'a',
#   's',
#   's',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'd',
#   'i',
#   'f',
#   'f',
#   'i',
#   'c',
#   'u',
#   'l',
#   't',
#   'i',
#   'e',
#   's',
#   ',',
#   ' ',
#   'A',
#   'n',
#   'd',
#   ' ',
#   'h',
#   'a',
#   'd',
#   ' ',
#   'a',
#   's',
#   ' ',
#   'a',
#   'm',
#   'p',
#   'l',
#   'e',
#   ' ',
#   'p',
#   'o',
#   'w',
#   'e',
#   'r',
#   ' ',
#   'a',
#   's',
#   ' ',
#   'I',
#   ' ',
#   'h',
#   'a',
#   'v',
#   'e',
#   ' ',
#   'w',
#   'i',
#   'l',
#   'l',
#   ',',
#   ' ',
#   'P',
#   'a',
#   'r',
#   'i',
#   's',
#   ' ',
#   's',
#   'h',
#   'o',
#   'u',
#   'l',
#   'd',
#   ' ',
#   'n',
#   'e',
#   "'",
#   'e',
#   'r',
#   ' ',
#   'r',
#   'e',
#   't',
#   'r',
#   'a',
#   'c',
#   't',
#   ' ',
#   'w',
#   'h',
#   'a',
#   't',
#   ' ',
#   'h',
#   'e',
#   ' ',
#   'h',
#   'a',
#   't',
#   'h',
#   ' ',
#   'd',
#   'o',
#   'n',
#   'e',
#   ' ',
#   'N',
#   'o',
#   'r',
#   ' ',
#   'f',
#   'a',
#   'i',
#   'n',
#   't',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'p',
#   'u',
#   'r',
#   's',
#   'u',
#   'i',
#   't',
#   '.',
#   ' ',
#   'S',
#   'i',
#   'r',
#   ',',
#   ' ',
#   'I',
#   ' ',
#   'p',
#   'r',
#   'o',
#   'p',
#   'o',
#   's',
#   'e',
#   ' ',
#   'n',
#   'o',
#   't',
#   ' ',
#   'm',
#   'e',
#   'r',
#   'e',
#   'l',
#   'y',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'm',
#   'y',
#   's',
#   'e',
#   'l',
#   'f',
#   ' ',
#   'T',
#   'h',
#   'e',
#   ' ',
#   'p',
#   'l',
#   'e',
#   'a',
#   's',
#   'u',
#   'r',
#   'e',
#   's',
#   ' ',
#   's',
#   'u',
#   'c',
#   'h',
#   ' ',
#   'a',
#   ' ',
#   'b',
#   'e',
#   'a',
#   'u',
#   't',
#   'y',
#   ' ',
#   'b',
#   'r',
#   'i',
#   'n',
#   'g',
#   's',
#   ' ',
#   'w',
#   'i',
#   't',
#   'h',
#   ' ',
#   'i',
#   't',
#   ';',
#   ' ',
#   'B',
#   'u',
#   't',
#   ' ',
#   'I',
#   ' ',
#   'w',
#   'o',
#   'u',
#   'l',
#   'd',
#   ' ',
#   'h',
#   'a',
#   'v',
#   'e',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   's',
#   'o',
#   'i',
#   'l',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'h',
#   'e',
#   'r',
#   ' ',
#   'f',
#   'a',
#   'i',
#   'r',
#   ' ',
#   'r',
#   'a',
#   'p',
#   'e',
#   ' ',
#   'W',
#   'i',
#   'p',
#   "'",
#   'd',
#   ' ',
#   'o',
#   'f',
#   'f',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   'h',
#   'o',
#   'n',
#   'o',
#   'u',
#   'r',
#   'a',
#   'b',
#   'l',
#   'e',
#   ' ',
#   'k',
#   'e',
#   'e',
#   'p',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'h',
#   'e',
#   'r',
#   '.',
#   ' ',
#   'W',
#   'h',
#   'a',
#   't',
#   ' ',
#   't',
#   'r',
#   'e',
#   'a',
#   's',
#   'o',
#   'n',
#   ' ',
#   'w',
#   'e',
#   'r',
#   'e',
#   ' ',
#   'i',
#   't',
#   ' ',
#   't',
#   'o',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'r',
#   'a',
#   'n',
#   's',
#   'a',
#   'c',
#   'k',
#   "'",
#   'd',
#   ' ',
#   'q',
#   'u',
#   'e',
#   'e',
#   'n',
#   ',',
#   ' ',
#   'D',
#   'i',
#   's',
#   'g',
#   'r',
#   'a',
#   'c',
#   'e',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'y',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'g',
#   'r',
#   'e',
#   'a',
#   't',
#   ' ',
#   'w',
#   'o',
#   'r',
#   't',
#   'h',
#   's',
#   ',',
#   ' ',
#   'a',
#   'n',
#   'd',
#   ' ',
#   's',
#   'h',
#   'a',
#   'm',
#   'e',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'm',
#   'e',
#   ',',
#   ' ',
#   'N',
#   'o',
#   'w',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'd',
#   'e',
#   'l',
#   'i',
#   'v',
#   'e',
#   'r',
#   ' ',
#   'h',
#   'e',
#   'r',
#   ' ',
#   'p',
#   'o',
#   's',
#   's',
#   'e',
#   's',
#   's',
#   'i',
#   'o',
#   'n',
#   ' ',
#   'u',
#   'p',
#   ' ',
#   'O',
#   'n',
#   ' ',
#   't',
#   'e',
#   'r',
#   'm',
#   's',
#   ' ',
#   'o',
#   'f',
#   ' ',
#   'b',
#   'a',
#   's',
#   'e',
#   ' ',
#   'c',
#   'o',
#   'm',
#   'p',
#   'u',
#   'l',
#   's',
#   'i',
#   'o',
#   'n',
#   '!',
#   ' ',
#   'C',
#   'a',
#   'n',
#   ' ',
#   'i',
#   't',
#   ' ',
#   'b',
#   'e',
#   ' ',
#   'T',
#   'h',
#   'a',
#   't',
#   ' ',
#   's',
#   'o',
#   ' ',
#   'd',
#   'e',
#   'g',
#   'e',
#   'n',
#   'e',
#   'r',
#   'a',
#   't',
#   'e',
#   ' ',
#   'a',
#   ' ',
#   's',
#   't',
#   'r',
#   'a',
#   'i',
#   'n',
#   ' ',
#   'a',
#   's',
#   ' ',
#   't',
#   'h',
#   'i',
#   's',
#   ' ',
#   'S',
#   'h',
#   'o',
#   'u',
#   'l',
#   'd',
#   ' ',
#   'o',
#   'n',
#   'c',
#   'e',
#   ' ',
#   's',
#   'e',
#   't',
#   ' ',
#   'f',
#   'o',
#   'o',
#   't',
#   'i',
#   'n',
#   'g',
#   ' ',
#   'i',
#   'n',
#   ' ',
#   'y',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'g',
#   'e',
#   'n',
#   'e',
#   'r',
#   'o',
#   'u',
#   's',
#   ' ',
#   'b',
#   'o',
#   's',
#   'o',
#   'm',
#   's',
#   '?',
#   ' ',
#   'T',
#   'h',
#   'e',
#   'r',
#   'e',
#   "'",
#   's',
#   ' ',
#   'n',
#   'o',
#   't',
#   ' ',
#   't',
#   'h',
#   'e',
#   ' ',
#   'm',
#   'e',
#   'a',
#   'n',
#   'e',
#   's',
#   't',
#   ' ',
#   's',
#   'p',
#   'i',
#   'r',
#   'i',
#   't',
#   ' ',
#   'o',
#   'n',
#   ' ',
#   'o',
#   'u',
#   'r',
#   ' ',
#   'p',
#   'a',
#   'r',
#   't',
#   'y',
#   ' ',
#   'W',
#   'i',
#   't',
#   'h',
#   'o',
#   'u',
#   't',
#   ' ',
#   'a',
#   ' ',
#   'h',
#   'e',
#   'a',
#   'r',
#   't',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'd',
#   'a',
#   'r',
#   'e',
#   ' ',
#   'o',
#   'r',
#   ' ',
#   's',
#   'w',
#   'o',
#   'r',
#   'd',
#   ' ',
#   't',
#   'o',
#   ' ',
#   'd',
#   'r',
#   'a',
#   'w',
#   ' ',
#   'W',
#   'h',
#   'e',
#   'n',
#   ' ',
#   'H',
#   'e',
#   'l',
#   'e',
#   'n',
#   ' ',
#   'i',
#   's',
#   ' ',
#   'd',
#   'e',
#   'f',
#   'e',
#   'n',
#   'd',
#   'e',
#   'd',
#   ';',
#   ' ',
#   'n',
#   'o',
#   'r',
#   ' ',
#   'n',
#   'o',
#   'n',
#   'e',
#   ' ',
#   's',
#   'o',
#   ' ',
#   'n',
#   'o',
#   'b',
#   'l',
#   'e',
#   ' ',
#   'W',
#   'h',
#   'o',
#   's',
#   'e',
#   ' ',
#   'l',
#   'i',
#   'f',
#   'e',
#   ' ',
#   'w',
#   'e',
#   'r',
#   'e',
#   ' ',
#   'i',
#   'l',
#   'l',
#   ' ',
#   'b',
#   'e',
#   's',
#   't',
#   'o',
#   ...]}

# %% [markdown]
# ### 1. Data pipeline
#
# Now, let us define how to build the data pipeline for federated learning:
#
# 1. To load the training and test data, we define a new dataset class, `Sent140Dataset`, which converts each user's tweets (features) into a `torch.Tensor`, discarding tweet metadata such as the date and time of the tweet. It also stores each tweet's sentiment (label) as well.

# %%
import itertools
import re
import string
import unicodedata

import torch
from torch.utils.data import Dataset

ALL_LETTERS = "\n !\"&'(),-.0123456789:;>?ABCDEFGHIJKLMNOPQRSTUVWXYZ[]abcdefghijklmnopqrstuvwxyz}"
NUM_LETTERS = len(ALL_LETTERS)

# 1. The Shakespeare dataset will store the phrases and corresponding next char for each user.

class Shakespeare(Dataset):
    def __init__(self, data_root, seq_len=80):
        self.data_root = data_root
        self.seq_len = seq_len

        with open(data_root, "r+") as f:
            self.dataset = json.load(f)

        self.data = {}
        self.targets = {}
        self.num_classes = 80  # next char prediction

        # Populate self.data and self.targets
        for user_id, user_data in self.dataset["user_data"].items():
            self.data[user_id] = self.process_x(list(user_data["x"]))
            self.targets[user_id] = self.process_y(list(user_data["y"]))

    def __len__(self):
        return len(self.data)

    def __iter__(self):
        for user_id in self.data.keys():
            yield self.__getitem__(user_id)

    def __getitem__(self, user_id: str):
        if user_id not in self.data or user_id not in self.targets:
            raise IndexError(f"User {user_id} is not in dataset")
        return self.data[user_id], self.targets[user_id]

    def process_x(self, raw_x_batch):
        x_batch = [self.word_to_indices(word) for word in raw_x_batch]
        return torch.LongTensor(x_batch)

    def process_y(self, raw_y_batch):
        y_batch = [self.letter_to_index(c) for c in raw_y_batch]
        return torch.LongTensor(y_batch)
    
    # ------------------------
    # utils for shakespeare dataset

    


    def _one_hot(self, index, size):
        '''returns one-hot vector with given size and value 1 at given index
        '''
        vec = [0 for _ in range(size)]
        vec[int(index)] = 1
        return vec
    
    def letter_to_index(self, letter):
        '''returns index of given letter in ALL_LETTERS
        '''
        return ALL_LETTERS.find(letter)


    def letter_to_vec(self, letter):
        '''returns one-hot representation of given letter
        '''
        index = ALL_LETTERS.find(letter)
        return self._one_hot(index, NUM_LETTERS)


    def word_to_indices(self, word):
        '''returns a list of character indices

        Args:
            word: string
        
        Return:
            indices: int list with length len(word)
        '''
        indices = []
        for c in word:
            indices.append(ALL_LETTERS.find(c))
        return indices

# %% [markdown]
# 2. We can now load the train and test dataset using `Sent140Dataset`.

# %%
# 2. Load the train and test datasets.
train_dataset = Shakespeare(
    data_root=TRAIN_DATA,
    seq_len=SEQ_LEN,
)
test_dataset = Shakespeare(
    data_root=TEST_DATA,
    seq_len=SEQ_LEN,
)

# %%
dset = train_dataset.dataset


for user_id, user_data in dset["user_data"].items():
    print(f"User {user_id}")
    print(list(user_data["x"]))
    print(list(user_data["y"]))
    break

for user_id, user_data in dset["user_data"].items():
    print(f"User {user_id}")
    print(train_dataset.process_y(user_data["y"]))
    break
# Out:
# User THE_HISTORY_OF_TROILUS_AND_CRESSIDA_PARIS
# ['Else might the world convince of levity As well my undertakings as your counsels', 'lse might the world convince of levity As well my undertakings as your counsels;', 'se might the world convince of levity As well my undertakings as your counsels; ', 'e might the world convince of levity As well my undertakings as your counsels; B', ' might the world convince of levity As well my undertakings as your counsels; Bu', 'might the world convince of levity As well my undertakings as your counsels; But', 'ight the world convince of levity As well my undertakings as your counsels; But ', 'ght the world convince of levity As well my undertakings as your counsels; But I', 'ht the world convince of levity As well my undertakings as your counsels; But I ', 't the world convince of levity As well my undertakings as your counsels; But I a', ' the world convince of levity As well my undertakings as your counsels; But I at', 'the world convince of levity As well my undertakings as your counsels; But I att', 'he world convince of levity As well my undertakings as your counsels; But I atte', 'e world convince of levity As well my undertakings as your counsels; But I attes', ' world convince of levity As well my undertakings as your counsels; But I attest', 'world convince of levity As well my undertakings as your counsels; But I attest ', 'orld convince of levity As well my undertakings as your counsels; But I attest t', 'rld convince of levity As well my undertakings as your counsels; But I attest th', 'ld convince of levity As well my undertakings as your counsels; But I attest the', 'd convince of levity As well my undertakings as your counsels; But I attest the ', ' convince of levity As well my undertakings as your counsels; But I attest the g', 'convince of levity As well my undertakings as your counsels; But I attest the go', 'onvince of levity As well my undertakings as your counsels; But I attest the god', 'nvince of levity As well my undertakings as your counsels; But I attest the gods', 'vince of levity As well my undertakings as your counsels; But I attest the gods,', 'ince of levity As well my undertakings as your counsels; But I attest the gods, ', 'nce of levity As well my undertakings as your counsels; But I attest the gods, y', 'ce of levity As well my undertakings as your counsels; But I attest the gods, yo', 'e of levity As well my undertakings as your counsels; But I attest the gods, you', ' of levity As well my undertakings as your counsels; But I attest the gods, your', 'of levity As well my undertakings as your counsels; But I attest the gods, your ', 'f levity As well my undertakings as your counsels; But I attest the gods, your f', ' levity As well my undertakings as your counsels; But I attest the gods, your fu', 'levity As well my undertakings as your counsels; But I attest the gods, your ful', 'evity As well my undertakings as your counsels; But I attest the gods, your full', 'vity As well my undertakings as your counsels; But I attest the gods, your full ', 'ity As well my undertakings as your counsels; But I attest the gods, your full c', 'ty As well my undertakings as your counsels; But I attest the gods, your full co', 'y As well my undertakings as your counsels; But I attest the gods, your full con', ' As well my undertakings as your counsels; But I attest the gods, your full cons', 'As well my undertakings as your counsels; But I attest the gods, your full conse', 's well my undertakings as your counsels; But I attest the gods, your full consen', ' well my undertakings as your counsels; But I attest the gods, your full consent', 'well my undertakings as your counsels; But I attest the gods, your full consent ', 'ell my undertakings as your counsels; But I attest the gods, your full consent G', 'll my undertakings as your counsels; But I attest the gods, your full consent Ga', 'l my undertakings as your counsels; But I attest the gods, your full consent Gav', ' my undertakings as your counsels; But I attest th ...
# [';', ' ', 'B', 'u', 't', ' ', 'I', ' ', 'a', 't', 't', 'e', 's', 't', ' ', 't', 'h', 'e', ' ', 'g', 'o', 'd', 's', ',', ' ', 'y', 'o', 'u', 'r', ' ', 'f', 'u', 'l', 'l', ' ', 'c', 'o', 'n', 's', 'e', 'n', 't', ' ', 'G', 'a', 'v', 'e', ' ', 'w', 'i', 'n', 'g', 's', ' ', 't', 'o', ' ', 'm', 'y', ' ', 'p', 'r', 'o', 'p', 'e', 'n', 's', 'i', 'o', 'n', ',', ' ', 'a', 'n', 'd', ' ', 'c', 'u', 't', ' ', 'o', 'f', ' ', 'A', 'l', 'l', ' ', 'f', 'e', 'a', 'r', 's', ' ', 'a', 't', 't', 'e', 'n', 'd', 'i', 'n', 'g', ' ', 'o', 'n', ' ', 's', 'o', ' ', 'd', 'i', 'r', 'e', ' ', 'a', ' ', 'p', 'r', 'o', 'j', 'e', 'c', 't', '.', ' ', 'F', 'o', 'r', ' ', 'w', 'h', 'a', 't', ',', ' ', 'a', 'l', 'a', 's', ',', ' ', 'c', 'a', 'n', ' ', 't', 'h', 'e', 's', 'e', ' ', 'm', 'y', ' ', 's', 'i', 'n', 'g', 'l', 'e', ' ', 'a', 'r', 'm', 's', '?', ' ', 'W', 'h', 'a', 't', ' ', 'p', 'r', 'o', 'p', 'u', 'g', 'n', 'a', 't', 'i', 'o', 'n', ' ', 'i', 's', ' ', 'i', 'n', ' ', 'o', 'n', 'e', ' ', 'm', 'a', 'n', "'", 's', ' ', 'v', 'a', 'l', 'o', 'u', 'r', ' ', 'T', 'o', ' ', 's', 't', 'a', 'n', 'd', ' ', 't', 'h', 'e', ' ', 'p', 'u', 's', 'h', ' ', 'a', 'n', 'd', ' ', 'e', 'n', 'm', 'i', 't', 'y', ' ', 'o', 'f', ' ', 't', 'h', 'o', 's', 'e', ' ', 'T', 'h', 'i', 's', ' ', 'q', 'u', 'a', 'r', 'r', 'e', 'l', ' ', 'w', 'o', 'u', 'l', 'd', ' ', 'e', 'x', 'c', 'i', 't', 'e', '?', ' ', 'Y', 'e', 't', ',', ' ', 'I', ' ', 'p', 'r', 'o', 't', 'e', 's', 't', ',', ' ', 'W', 'e', 'r', 'e', ' ', 'I', ' ', 'a', 'l', 'o', 'n', 'e', ' ', 't', 'o', ' ', 'p', 'a', 's', 's', ' ', 't', 'h', 'e', ' ', 'd', 'i', 'f', 'f', 'i', 'c', 'u', 'l', 't', 'i', 'e', 's', ',', ' ', 'A', 'n', 'd', ' ', 'h', 'a', 'd', ' ', 'a', 's', ' ', 'a', 'm', 'p', 'l', 'e', ' ', 'p', 'o', 'w', 'e', 'r', ' ', 'a', 's', ' ', 'I', ' ', 'h', 'a', 'v', 'e', ' ', 'w', 'i', 'l', 'l', ',', ' ', 'P', 'a', 'r', 'i', 's', ' ', 's', 'h', 'o', 'u', 'l', 'd', ' ', 'n', 'e', "'", 'e', 'r', ' ', 'r', 'e', 't', 'r', 'a', 'c', 't', ' ', 'w', 'h', 'a', 't', ' ', 'h', 'e', ' ', 'h', 'a', 't', 'h', ' ', 'd', 'o', 'n', 'e', ' ', 'N', 'o', 'r', ' ', 'f', 'a', 'i', 'n', 't', ' ', 'i', 'n', ' ', 't', 'h', 'e', ' ', 'p', 'u', 'r', 's', 'u', 'i', 't', '.', ' ', 'S', 'i', 'r', ',', ' ', 'I', ' ', 'p', 'r', 'o', 'p', 'o', 's', 'e', ' ', 'n', 'o', 't', ' ', 'm', 'e', 'r', 'e', 'l', 'y', ' ', 't', 'o', ' ', 'm', 'y', 's', 'e', 'l', 'f', ' ', 'T', 'h', 'e', ' ', 'p', 'l', 'e', 'a', 's', 'u', 'r', 'e', 's', ' ', 's', 'u', 'c', 'h', ' ', 'a', ' ', 'b', 'e', 'a', 'u', 't', 'y', ' ', 'b', 'r', 'i', 'n', 'g', 's', ' ', 'w', 'i', 't', 'h', ' ', 'i', 't', ';', ' ', 'B', 'u', 't', ' ', 'I', ' ', 'w', 'o', 'u', 'l', 'd', ' ', 'h', 'a', 'v', 'e', ' ', 't', 'h', 'e', ' ', 's', 'o', 'i', 'l', ' ', 'o', 'f', ' ', 'h', 'e', 'r', ' ', 'f', 'a', 'i', 'r', ' ', 'r', 'a', 'p', 'e', ' ', 'W', 'i', 'p', "'", 'd', ' ', 'o', 'f', 'f', ' ', 'i', 'n', ' ', 'h', 'o', 'n', 'o', 'u', 'r', 'a', 'b', 'l', 'e', ' ', 'k', 'e', 'e', 'p', 'i', 'n', 'g', ' ', 'h', 'e', 'r', '.', ' ', 'W', 'h', 'a', 't', ' ', 't', 'r', 'e', 'a', 's', 'o', 'n', ' ', 'w', 'e', 'r', 'e', ' ', 'i', 't', ' ', 't', 'o', ' ', 't', 'h', 'e', ' ', 'r', 'a', 'n', 's', 'a', 'c', 'k', "'", 'd', ' ', 'q', 'u', 'e', 'e', 'n', ',', ' ', 'D', 'i', 's', 'g', 'r', 'a', 'c', 'e', ' ', 't', 'o', ' ', 'y', 'o', 'u', 'r', ' ', 'g', 'r', 'e', 'a', 't', ' ', 'w', 'o', 'r', 't', 'h', 's', ',', ' ', 'a', 'n', 'd', ' ', 's', 'h', 'a', 'm', 'e', ' ', 't', 'o', ' ', 'm', 'e', ',', ' ', 'N', 'o', 'w', ' ', 't', 'o', ' ', 'd', 'e', 'l', 'i', 'v', 'e', 'r', ' ', 'h', 'e', 'r', ' ', 'p', 'o', 's', 's', 'e', 's', 's', 'i', 'o', 'n', ' ', 'u', 'p', ' ', 'O', 'n', ' ', 't', 'e', 'r', 'm', 's', ' ', 'o', 'f', ' ', 'b', 'a', 's', 'e', ' ', 'c', 'o', 'm', 'p', 'u', 'l', 's', 'i', 'o', 'n', '!', ' ', 'C', 'a', 'n', ' ', 'i', 't', ' ', 'b', 'e', ' ', 'T', 'h', 'a', 't', ' ', 's', 'o', ' ', 'd', 'e', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'a', ' ', 's', 't', 'r', 'a', 'i', 'n', ' ', 'a', 's', ' ', 't', 'h', 'i', 's', ' ', 'S', ...
# User THE_HISTORY_OF_TROILUS_AND_CRESSIDA_PARIS
# tensor([22,  1, 26,  ..., 65, 10,  1])

# %% [markdown]
# Recall our `EXAMPLE_USER` from earlier? Their data now looks like this:

# %%
train_dataset[EXAMPLE_USER]
# Out:
# (tensor([[29, 64, 71,  ..., 57, 64, 71],
#          [64, 71, 57,  ..., 64, 71, 22],
#          [71, 57,  1,  ..., 71, 22,  1],
#          ...,
#          [70, 67, 61,  ...,  1, 60, 61],
#          [67, 61, 64,  ..., 60, 61, 65],
#          [61, 64, 73,  ..., 61, 65, 10]]),
#  tensor([22,  1, 26,  ..., 65, 10,  1]))

# %% [markdown]
# To complete our data pipeline, we only need to
#
# 3. Create a data loader, which will batchify training, eval, and test data. There is no need to create a sharder since each data sample is already associated with a user. For each dataset, the data loader splits each client's data into batches of size `batch_size`. We choose not to drop the last batch.
#
# 4. Lastly, wrap the data loader with a data provider and return it.
# The data provider creates clients from the groupings in the data loader and adds metadata (e.g. number of examples, number of batches per client).
# Our data is now formatted such that the trainer will accept it.

# %%
from flsim.utils.example_utils import LEAFDataLoader, DataProvider

# 3. Batchify training, eval, and test data. Note that train_dataset is already sharded.
dataloader = LEAFDataLoader(
    train_dataset,
    test_dataset,
    test_dataset,
    batch_size=LOCAL_BATCH_SIZE,
    drop_last=False,
)

# 4. Wrap the data loader with a data provider.
data_provider = DataProvider(dataloader)
print(f"\nClients in total: {data_provider.num_train_users()}")
# Out:
# Creating FL User: 38user [00:01, 27.36user/s]
# Creating FL User: 5user [00:00,  8.90user/s]
# Creating FL User: 5user [00:00,  7.12user/s]
# Clients in total: 38

# %% [markdown]
# ### 2. Create the model
#
# Now, let's see how we can create a model that is compatible with FL-training.
#
# 1. First, we define a standard, non-FL sentiment classification PyTorch `nn.Module`. In this tutorial we use a simple char-LSTM with an embedding, LSTM, and linear layer.
#
# 2. Create a `torch.device` and choose where the model will be allocated (CUDA or CPU).
#
# As with the data pipeline, these steps are identical to creating a model in non-federated learning. Note that in contrast to non-FL learning, we haven't moved the model to device yet.

# %%
from torch import nn
import torch.nn.functional as F

class CharLSTM(nn.Module):
    def __init__(
        self,
        num_classes,
        n_hidden=256,
        num_embeddings=80,
        embedding_dim=8,
        seq_len=80,
        dropout_rate=0,
    ):
        super().__init__()
        self.dropout_rate = dropout_rate
        self.n_hidden = n_hidden
        self.num_classes = num_classes
        self.seq_len = seq_len
        self.num_embeddings = num_embeddings

        self.embedding = nn.Embedding(
            num_embeddings=self.num_embeddings, embedding_dim=embedding_dim
        )
        self.lstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=self.n_hidden,
            num_layers=2,
            batch_first=True,
            dropout=self.dropout_rate,
        )
        self.dropout = nn.Dropout(p=self.dropout_rate)
        self.fc = nn.Linear(self.n_hidden, self.num_classes)

    def forward(self, sentence):
        embeds = self.embedding(sentence)  
        lstm_out, _ = self.lstm(embeds)
        final_hidden_state = lstm_out[:, -1]
        return self.fc(self.dropout(final_hidden_state))

# %% [markdown]
# We initialize our model with such parameters that it is compatible with our dataset.

# %%
import torch

# 1. Define our model, a simple char-LSTM.
model = CharLSTM(
    num_classes=train_dataset.num_classes,
    n_hidden=256,
    num_embeddings=80,
    embedding_dim=8,
    seq_len=SEQ_LEN,
    dropout_rate=0.1,
)

# 2. Choose where the model will be allocated.
cuda_enabled = torch.cuda.is_available() and USE_CUDA
gpu = 2
device = torch.device("cuda:{}".format(gpu) if cuda_enabled else "cpu")

model, device
# Out:
# (CharLSTM(
#    (embedding): Embedding(80, 8)
#    (lstm): LSTM(8, 256, num_layers=2, batch_first=True, dropout=0.1)
#    (dropout): Dropout(p=0.1, inplace=False)
#    (fc): Linear(in_features=256, out_features=80, bias=True)
#  ),
#  device(type='cuda', index=2))

# %% [markdown]
# As with the data pipeline, there are a few extra steps that we need to take to make sure that our model is compatible with FL. In particular, we need to
#
# 3. Wrap the PyTorch module with the FLSim `FLModel`, an abstracted version of a FL-friendly model class that is accepted by the trainer and handles metric collection, as well as the forward pass for both training and evaluation. We can recover our `nn.Module` by calling `FLModel.fl_get_module()`
#
# 4. Move the model to GPU and enable CUDA if desired. `FLModel.fl_cuda()` internally calls `model.to(device)` to move the model to GPU.

# %%
from flsim.utils.example_utils import FLModel

# 3. Wrap the model with FLModel.
global_model = FLModel(model, device)
assert(global_model.fl_get_module() == model)

# 4. Move the model to GPU and enable CUDA if desired.
if cuda_enabled:
    global_model.fl_cuda()

# %% [markdown]
# ### 3. Metrics Reporting
#
# After having created our data pipeline and FL model, we will now create our metrics reporter.
# The metrics reporter allows us to collect, evaluate, and report relevant training, aggregation, and evaluation/test metrics as well as log them onto TensorBoard.

# %%
from flsim.interfaces.metrics_reporter import Channel
from flsim.utils.example_utils import MetricsReporter

# Create a metric reporter.
metrics_reporter = MetricsReporter([Channel.TENSORBOARD, Channel.STDOUT])

# %% [markdown]
# There are three functions that are of particular interest:
#
# 1. `compute_scores` computes the metrics of interest for both training and aggregation (if desired) as well as evaluation/test.
#
# 2. `create_eval_metrics` creates a dictionary that stores the value for each eval metric.
#
# 3. `compare_metrics` compares the current eval metrics that are returned by `create_eval_metrics` to the best eval metrics so far.
#
# For this tutorial, our only metric of interest is top-1 accuracy. In general, as with the data loading and model, you should write your own metrics reporter depending on the task.

# %%
import inspect

if VERBOSE:
    print(inspect.getsource(MetricsReporter.compute_scores))
    print(inspect.getsource(MetricsReporter.create_eval_metrics))
    print(inspect.getsource(MetricsReporter.compare_metrics))

# %% [markdown]
# ### 4. Hyperparameters
#
# We can represent the hyperparameters for FL training in a JSON config for ease of representation and we convert the JSON config to OmegaConf before passing it to the FL trainer.
#
# In particular, we specify a FedAvg with LR implementation with 10 users per round.

# %%
import flsim.configs
from flsim.utils.config_utils import fl_config_from_json
from omegaconf import OmegaConf

json_config = {
    "trainer": {
        "_base_": "base_sync_trainer",
        "server": {
            "_base_": "base_sync_server",
            "server_optimizer": {
                # there are different types of server optimizers
                # fed avg with lr requires a learning rate, whereas e.g. fed_avg doesn't
                "_base_": "base_fed_avg_with_lr",
                # server's learning rate
                "lr": 1,
                # server's global momentum
                "momentum": 0.0
            },
            # aggregate client models into a single model by taking their weighted sum
            "aggregation_type": "WEIGHTED_AVERAGE",
            # type of user selection sampling
            "active_user_selector": {
                "_base_": "base_uniformly_random_active_user_selector"
            }
        },
        "client": {
            # number of client's local epochs
            "epochs": 10,
            "optimizer": {
                # client's optimizer
                "_base_": "base_optimizer_sgd",
                # client's local learning rate
                "lr": 0.8,
                # client's local momentum
                "momentum": 0
            }
        },
        # number of users per round for aggregation
        "users_per_round": 10,
        # total number of global epochs
        # total #rounds = ceil(total_users / users_per_round) * epochs
        "epochs": 20,
        # frequency of reporting train metrics
        "train_metrics_reported_per_epoch": 10,
        # keep the trained model always (as opposed to only when it
        # performs better than the previous model on eval)
        "always_keep_trained_model": False,
        # frequency of evaluation per epoch
        "eval_epoch_frequency": 1,
        "do_eval": True,
        # should we report train metrics after global aggregation
        "report_train_metrics_after_aggregation": True
    }
}

cfg = fl_config_from_json(json_config)
if VERBOSE: print(OmegaConf.to_yaml(cfg))
# Out:
# /home/tomas/Documents/git/FLSim/qafel/lib/python3.10/site-packages/flsim/utils/config_utils.py:198: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   with initialize(config_path=None):

# %% [markdown]
# ### 5. Training
# Recall that we already built the data provider and created a model compatible with FL training.
# We also initialized a metrics reporter and set our desired hyperparameters.
#
# Now, we only need to instantiate the trainer with the model and hyperparameter config we defined earlier to launch the FL training flow. We run FL training with the above JSON config and utilize `eval_score` to store the final evaluation metrics.

# %%
from hydra.utils import instantiate

# Instantiate the trainer.
trainer = instantiate(cfg.trainer, model=global_model, cuda_enabled=cuda_enabled)   

# Launch FL training.
final_model, eval_score = trainer.train(
    data_provider=data_provider,
    metrics_reporter=metrics_reporter,
    num_total_users=data_provider.num_train_users(),
    distributed_world_size=1,
)
# Out:
# Round:   0%|          | 0/4 [00:00<?, ?round/s]]/home/tomas/Documents/git/FLSim/qafel/lib/python3.10/site-packages/torch/nn/modules/rnn.py:911: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at ../aten/src/ATen/native/cudnn/RNN.cpp:1424.)
#   result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,

# %% [markdown]
# After training finishes, we evaluate the model and report the accuracy on the test set before finishing this tutorial.

# %%
# We can now test our trained model.
trainer.test(
    data_provider=data_provider,
    metrics_reporter=MetricsReporter([Channel.STDOUT]),
)

# %% [markdown]
# ## Summary
#
# In this tutorial, we first showed how to get and preprocess LEAF's Sent140 dataset.
# We then built a data provider by splitting each client's data into batches.
# We defined a simple char-LSTM as our model, wrapped it with a model compatible with FL training, and moved it to GPU.
# Lastly, we set the hyperparameters for FL training, launched the training flow, and evaluated our model.

# %% [markdown]
# ### Additional resources
#
# - For a more in-depth understanding of this tutorial, check out [example_utils.py](https://github.com/facebookresearch/FLSim/blob/main/flsim/utils/example_utils.py) where we define the data loader, data provider, `FLModel`, and metrics reporter that we use in this tutorial.
#
# - [FLSim tutorials](https://github.com/facebookresearch/FLSim/tree/main/tutorials) - check out our other tutorial on image classification.
#
# - Kairouz et al. (2021): [Advances and Open Problems in Federated Learning](https://arxiv.org/pdf/1912.04977.pdf). As the title suggests, an in-depth overview of advances and open problems in FL.
#
# - If you're interested in federated learning with differential privacy, take a look at [Opacus](https://opacus.ai/), a library that enables training PyTorch models with differential privacy.
# You can find a blog post introducing Opacus [here](https://ai.facebook.com/blog/introducing-opacus-a-high-speed-library-for-training-pytorch-models-with-differential-privacy/).
